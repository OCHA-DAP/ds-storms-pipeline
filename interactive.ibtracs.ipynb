# %%
from src.pipelines.ibtracs import run_ibtracs

run_ibtracs("dev", "ALL", True, 10000)
# Out:
# 2025-08-29 22:06:21 - src.pipelines.ibtracs - INFO - Starting IBTrACS ETL pipeline...
# 2025-08-29 22:06:24 - src.pipelines.ibtracs - INFO - Retrieving ALL from IBTrACS...
#
# KeyboardInterrupt
