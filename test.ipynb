# %%
import ocha_lens as lens
from src.pipelines.ibtracs import process_tracks

# %%
# %pip install hypothesis
# Out:
# ...
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.4/530.4 kB 8.2 MB/s eta 0:00:00
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = lens.ibtracs.load_ibtracs(
    file_path="raw/IBTrACS.last3years.v04r01.nc", dataset="last3years"
)

# Process tracks and add them to the database
process_tracks(dataset=dataset, engine=None, chunksize=None)
# Out:
# skipped!
# /Users/hannahker/Desktop/ds-cyclones-pipeline/src/pipelines/ibtracs.py:63: UserWarning: Geometry column does not contain geometry.
#   tracks_geo["geometry"] = tracks_geo["geometry"].apply(lambda x: x.wkt)
#       wind_speed  pressure  max_wind_radius  last_closed_isobar_radius  \
# 0             35       999               65                        200
# 1             40       999               46                        178
# 2             45       998               26                        156
# 3             53       994               21                        156
# 4             60       989               15                        156
# ...          ...       ...              ...                        ...
# 8320          35      1000             <NA>                        119
# 8321          35      1000             <NA>                        119
# 8322          30      1002             <NA>                        119
# ...
